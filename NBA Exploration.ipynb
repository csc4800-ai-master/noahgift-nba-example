# %%
import pandas as pd
nba=pd.read_csv("data/nba-per-game-2017.csv")
nba.describe()
# Out:
#                Rk         Age           G           MP         PER  \
# count  595.000000  595.000000  595.000000   595.000000  595.000000
# mean   244.085714   26.411765   48.431933  1090.682353   12.731261
# std    140.572151    4.261273   26.306597   835.227295    6.040422
# min      1.000000   19.000000    1.000000     1.000000  -35.300000
# 25%    124.500000   23.000000   24.000000   321.000000    9.600000
# 50%    244.000000   26.000000   55.000000  1013.000000   12.700000
# 75%    364.500000   29.000000   73.000000  1757.500000   15.550000
# max    486.000000   40.000000   82.000000  3048.000000   31.500000
#
#               TS%        3PAr         FTr        ORB%        DRB%  ...  \
# count  593.000000  593.000000  593.000000  595.000000  595.000000  ...
# mean     0.526830    0.321577    0.270499    4.908908   15.141681  ...
# std      0.093636    0.211414    0.213896    4.200670    7.498764  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...
